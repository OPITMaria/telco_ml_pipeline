# %% [markdown]
# # INTERNET Notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import average_precision_score, roc_auc_score, accuracy_score, f1_score

import optuna
import catboost as cb
import xgboost as xgb
import lightgbm as lgb

# %%
df = pd.read_csv('df_train_internet_only.csv')

# %%
num_col = ['tenure', 'totalcharges', 'monthlycharges']
target = 'churn'
X_col = [c for c in df.columns if c != target]
cat_col = [c for c in X_col if c not in num_col]

# %%
sns.histplot(data=df, x='churn')
# Out:
# <Axes: xlabel='churn', ylabel='Count'>

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 5))
for col, ax in zip(num_col, axes):
    sns.histplot(
        data=df, x=col, kde=True, ax=ax, hue=target, binwidth=df[col].std() /5, edgecolor=None
    )

# %%
probability_of_churn_given_flag = df[df[target]][cat_col].sum() / df[cat_col].sum()
probability_of_churn_given_flag = probability_of_churn_given_flag.sort_values(ascending = False)

plt.figure(figsize=(10, 6))
sns.barplot(data=probability_of_churn_given_flag, orient= 'h')
plt.xlabel('Mean Value')
plt.ylabel('Categories')
plt.show()

# %%
scaler = RobustScaler()
df_scaled = df.copy()
df_scaled.loc[:, num_col] = scaler.fit_transform(df_scaled[num_col])

# %%
pca = PCA()
X_pca = pca.fit_transform(df_scaled[X_col])
importances = pca.explained_variance_ratio_ / np.sum(pca.explained_variance_ratio_)
print(pd.Series(importances)[:3])
# Out:
# 0    0.308159
# 1    0.115089
# 2    0.061302
# dtype: float64

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=df[target], cmap="viridis", alpha=0.7)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Scatter Plot")
plt.colorbar(label="Target")
plt.grid()
plt.show()

# %%
fig = px.scatter_3d(
    x=X_pca[:, 0],
    y=X_pca[:, 1],
    z=X_pca[:, 2],
    color=df[target],
    labels={"x": "Principal Component 1", "y": "Principal Component 2", "z": "Principal Component 3"},
    title="3D PCA Scatter Plot",
)

fig.update_traces(marker={"size": 3})
fig.update_layout(width=1000, height=800)
fig.show()

# %%
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(df_scaled[X_col])

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=df[target], cmap="viridis", alpha=0.7)
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.title("t-SNE Scatter Plot")
plt.colorbar(label="Target")
plt.grid()
plt.show()

# %% [markdown]
# ## Modelling

# %%
X = df[X_col]
y = df[target]

# %%
X, X_test, y, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# ## CatBoost

# %% [markdown]
# #### Parameters research

# %%
def objective(trial):
    param = {
        'iterations': trial.suggest_int('iterations', 500, 1000),
        'depth': trial.suggest_int('depth', 4, 8),
        'learning_rate': trial.suggest_float('learning_rate', 1e-2, 0.1),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 16, 20),
        'subsample': trial.suggest_float('subsample', 0.4, 0.7),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 0, 5),
        'random_strength': trial.suggest_float('random_strength', 0.1, 2),
        'loss_function': 'Logloss',
        'eval_metric': 'Accuracy',
        'task_type': 'CPU',
    }

    
    kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    scores = []
    
    for train_index, valid_index in kf.split(X, y):
        X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
        y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
        
        scaler = MinMaxScaler()
        X_train.loc[:, num_col] = scaler.fit_transform(X_train[num_col])
        X_valid.loc[:, num_col] = scaler.transform(X_valid[num_col])
    
        # Create CatBoost Pool
        train_pool = cb.Pool(X_train, y_train)
        valid_pool = cb.Pool(X_valid, y_valid)
        
        # Initialize and train model
        model = cb.CatBoostClassifier(**param, 
                                      verbose=False, 
                                      early_stopping_rounds=15
                                      )
        model.fit(train_pool, 
                  eval_set=valid_pool, 
                  plot=False)
        
        # Predict and calculate accuracy
        preds = model.predict(valid_pool)
        scores.append(roc_auc_score(y_valid, preds))
    
    mean_score = np.mean(scores)
    return mean_score

# Create Optuna study
study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=42),  pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=3))

# Optimize
study.optimize(objective, n_trials=20)

# Print best parameters
print("Best trial:", study.best_trial.params)
# Out:
# [I 2024-12-11 13:31:37,422] A new study created in memory with name: no-name-ce213d28-07da-4d9c-bdad-ba73b64700f6
# [I 2024-12-11 13:31:38,621] Trial 0 finished with value: 0.7058182813355227 and parameters: {'iterations': 687, 'depth': 8, 'learning_rate': 0.07587945476302646, 'l2_leaf_reg': 18.394633936788146, 'subsample': 0.44680559213273097, 'min_data_in_leaf': 0, 'random_strength': 0.21035886311957896}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:39,342] Trial 1 finished with value: 0.6816871921182266 and parameters: {'iterations': 933, 'depth': 7, 'learning_rate': 0.0737265320016441, 'l2_leaf_reg': 16.082337977183208, 'subsample': 0.6909729556485982, 'min_data_in_leaf': 4, 'random_strength': 0.5034443102887247}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:39,886] Trial 2 finished with value: 0.6805541871921182 and parameters: {'iterations': 591, 'depth': 4, 'learning_rate': 0.0373818018663584, 'l2_leaf_reg': 18.09902572652895, 'subsample': 0.5295835055926348, 'min_data_in_leaf': 1, 'random_strength': 1.262520499972521}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:40,461] Trial 3 finished with value: 0.7050779967159276 and parameters: {'iterations': 569, 'depth': 5, 'learning_rate': 0.04297256589643226, 'l2_leaf_reg': 17.824279936868145, 'subsample': 0.6355527884179041, 'min_data_in_leaf': 1, 'random_strength': 1.077045432985862}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:41,036] Trial 4 finished with value: 0.702603995621237 and parameters: {'iterations': 796, 'depth': 4, 'learning_rate': 0.06467903667112945, 'l2_leaf_reg': 16.682096494749167, 'subsample': 0.41951547789558385, 'min_data_in_leaf': 5, 'random_strength': 1.9347008628416629}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:41,654] Trial 5 finished with value: 0.6968596059113301 and parameters: {'iterations': 905, 'depth': 5, 'learning_rate': 0.018790490260574548, 'l2_leaf_reg': 18.736932106048627, 'subsample': 0.5320457481218803, 'min_data_in_leaf': 0, 'random_strength': 1.0408361292114134}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:42,471] Trial 6 finished with value: 0.678411330049261 and parameters: {'iterations': 517, 'depth': 8, 'learning_rate': 0.03329019834400153, 'l2_leaf_reg': 18.65008913741593, 'subsample': 0.4935133228268233, 'min_data_in_leaf': 3, 'random_strength': 1.1387495307522313}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:43,369] Trial 7 finished with value: 0.6901710454296661 and parameters: {'iterations': 592, 'depth': 8, 'learning_rate': 0.07976195410250031, 'l2_leaf_reg': 19.757995766256755, 'subsample': 0.6684482051282946, 'min_data_in_leaf': 3, 'random_strength': 1.851561046543922}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:43,923] Trial 8 finished with value: 0.6825123152709359 and parameters: {'iterations': 544, 'depth': 4, 'learning_rate': 0.014070456001948426, 'l2_leaf_reg': 17.301321323053056, 'subsample': 0.5166031869068446, 'min_data_in_leaf': 1, 'random_strength': 1.6746012673886657}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:44,488] Trial 9 finished with value: 0.6883853311439518 and parameters: {'iterations': 678, 'depth': 5, 'learning_rate': 0.058842647484242366, 'l2_leaf_reg': 16.56369689989905, 'subsample': 0.6406590942262118, 'min_data_in_leaf': 0, 'random_strength': 1.975085179540983}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:45,188] Trial 10 finished with value: 0.6895840175150519 and parameters: {'iterations': 768, 'depth': 7, 'learning_rate': 0.09725833997090795, 'l2_leaf_reg': 19.72916136764715, 'subsample': 0.4046103211984313, 'min_data_in_leaf': 2, 'random_strength': 0.128774050495238}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:45,762] Trial 11 finished with value: 0.6686453201970444 and parameters: {'iterations': 668, 'depth': 6, 'learning_rate': 0.04416438190782014, 'l2_leaf_reg': 17.773764112935478, 'subsample': 0.6091467695020284, 'min_data_in_leaf': 1, 'random_strength': 0.75095343759553}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:46,356] Trial 12 finished with value: 0.6770443349753694 and parameters: {'iterations': 678, 'depth': 6, 'learning_rate': 0.08935962033884365, 'l2_leaf_reg': 18.490563442351625, 'subsample': 0.5770529099692607, 'min_data_in_leaf': 0, 'random_strength': 0.254613133667712}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:46,971] Trial 13 finished with value: 0.6998180076628352 and parameters: {'iterations': 845, 'depth': 5, 'learning_rate': 0.049738096951215505, 'l2_leaf_reg': 19.087696049520286, 'subsample': 0.47044800939509646, 'min_data_in_leaf': 2, 'random_strength': 0.7797774851216911}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:47,735] Trial 14 finished with value: 0.6830897646414889 and parameters: {'iterations': 622, 'depth': 7, 'learning_rate': 0.06666064211867517, 'l2_leaf_reg': 17.52355463417343, 'subsample': 0.5857503632212279, 'min_data_in_leaf': 1, 'random_strength': 1.407636072705378}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:48,372] Trial 15 finished with value: 0.6870443349753694 and parameters: {'iterations': 731, 'depth': 6, 'learning_rate': 0.027248923274293867, 'l2_leaf_reg': 18.205075081176947, 'subsample': 0.4543577984202467, 'min_data_in_leaf': 0, 'random_strength': 0.7648379884284591}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:49,227] Trial 16 finished with value: 0.6965544608648055 and parameters: {'iterations': 725, 'depth': 8, 'learning_rate': 0.08216330623462477, 'l2_leaf_reg': 17.246269547985936, 'subsample': 0.6359883615309995, 'min_data_in_leaf': 2, 'random_strength': 0.4582941745924918}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:49,816] Trial 17 finished with value: 0.7006910235358512 and parameters: {'iterations': 506, 'depth': 5, 'learning_rate': 0.054337018779616865, 'l2_leaf_reg': 19.18600762368951, 'subsample': 0.5652180285495845, 'min_data_in_leaf': 1, 'random_strength': 0.952841088452199}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:50,493] Trial 18 finished with value: 0.6954926108374384 and parameters: {'iterations': 627, 'depth': 7, 'learning_rate': 0.04477167805689537, 'l2_leaf_reg': 17.791275733064257, 'subsample': 0.44061700427063166, 'min_data_in_leaf': 0, 'random_strength': 1.574067283494288}. Best is trial 0 with value: 0.7058182813355227.
# [I 2024-12-11 13:31:51,061] Trial 19 finished with value: 0.6793240284619595 and parameters: {'iterations': 835, 'depth': 5, 'learning_rate': 0.07203580467007205, 'l2_leaf_reg': 16.933738306991973, 'subsample': 0.4891088847919065, 'min_data_in_leaf': 2, 'random_strength': 0.5234173675717456}. Best is trial 0 with value: 0.7058182813355227.
# Best trial: {'iterations': 687, 'depth': 8, 'learning_rate': 0.07587945476302646, 'l2_leaf_reg': 18.394633936788146, 'subsample': 0.44680559213273097, 'min_data_in_leaf': 0, 'random_strength': 0.21035886311957896}

# %% [markdown]
# #### Testing

# %%
best_params = {'iterations': 862, 'depth': 8, 'learning_rate': 0.09169350952718329, 'l2_leaf_reg': 17.280624018040182, 'subsample': 0.48223683658151323, 'min_data_in_leaf': 5, 'random_strength': 0.4117055183567362}
model = cb.CatBoostClassifier(**best_params, verbose=False)
train_pool = cb.Pool(X, y)
test_pool = cb.Pool(X_test, y_test)
model.fit(train_pool)

# %%
print('CatBoost scores')
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"RocAuc: {roc_auc_score(y_test, y_pred)}")
print(f"F1 : {f1_score(y_test, y_pred)}")
# Out:
# CatBoost scores
# Accuracy: 0.7621951219512195
# RocAuc: 0.6869918699186992
# F1 : 0.5301204819277109

# %% [markdown]
# ## XGBoost

# %% [markdown]
# #### Parameters research

# %%
def objective(trial):
    param = {
        "objective": "binary:logistic",
        "eval_metric": "aucpr",
        'n_estimators': trial.suggest_int('n_estimators', 800, 1200), 
        "booster": trial.suggest_categorical("booster", ["gbtree", "dart"]),
        "lambda": trial.suggest_float("lambda", 1e-3, 2),
        "alpha": trial.suggest_float("alpha", 1e-3, 2),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "eta": trial.suggest_float("eta", 1e-2, 0.3),
        "gamma": trial.suggest_float("gamma", 1e-3, 3),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 7),
        "subsample": trial.suggest_float("subsample", 0.6, 0.95),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 0.95),
        "grow_policy": trial.suggest_categorical(
            "grow_policy", ["depthwise", "lossguide"]
        ),
        "max_bin": trial.suggest_int("max_bin", 64, 255)
    }

    kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    scores = []
    for train_index, valid_index in kf.split(X, y):
        X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
        y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
    
        model = xgb.XGBClassifier(**param, early_stopping_rounds=15)
        model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)], verbose=False)
        preds = model.predict(X_valid)
        scores.append(accuracy_score(y_valid, preds))
    
    mean_score = np.mean(scores)   
    return mean_score

study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=42), pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=3))
study.optimize(objective, n_trials=20)

print("Best trial:", study.best_trial.params)
# Out:
# [I 2024-12-11 13:31:53,856] A new study created in memory with name: no-name-75103916-72bb-4acc-8771-9ce4b8c7db4f
# [I 2024-12-11 13:31:54,469] Trial 0 finished with value: 0.7585695006747637 and parameters: {'n_estimators': 950, 'booster': 'gbtree', 'lambda': 1.197718309909876, 'alpha': 0.31288126224443064, 'max_depth': 4, 'eta': 0.026844247528777843, 'gamma': 2.5986622611790304, 'min_child_weight': 5, 'subsample': 0.8478254022286159, 'colsample_bytree': 0.6072045730035308, 'grow_policy': 'depthwise', 'max_bin': 104}. Best is trial 0 with value: 0.7585695006747637.
# [I 2024-12-11 13:31:56,042] Trial 1 finished with value: 0.7951417004048583 and parameters: {'n_estimators': 872, 'booster': 'dart', 'lambda': 1.0499881068328434, 'alpha': 0.8644580922655895, 'max_depth': 5, 'eta': 0.18743733946949004, 'gamma': 0.41934208809547346, 'min_child_weight': 3, 'subsample': 0.7282266451527921, 'colsample_bytree': 0.7596244944759625, 'grow_policy': 'depthwise', 'max_bin': 162}. Best is trial 1 with value: 0.7951417004048583.
# [I 2024-12-11 13:31:57,200] Trial 2 finished with value: 0.8057354925775979 and parameters: {'n_estimators': 1037, 'booster': 'dart', 'lambda': 0.34187772325089577, 'alpha': 0.13103813437757375, 'max_depth': 10, 'eta': 0.2900332895916222, 'gamma': 2.425383647001267, 'min_child_weight': 3, 'subsample': 0.6341852399022343, 'colsample_bytree': 0.8394815592792548, 'grow_policy': 'depthwise', 'max_bin': 159}. Best is trial 2 with value: 0.8057354925775979.
# [I 2024-12-11 13:31:57,761] Trial 3 finished with value: 0.7717273954116058 and parameters: {'n_estimators': 813, 'booster': 'gbtree', 'lambda': 1.32538204642361, 'alpha': 0.6241104411027325, 'max_depth': 7, 'eta': 0.1685459810095511, 'gamma': 0.5553785121210556, 'min_child_weight': 7, 'subsample': 0.87129648817639, 'colsample_bytree': 0.9288246295474661, 'grow_policy': 'depthwise', 'max_bin': 240}. Best is trial 2 with value: 0.8057354925775979.
# [I 2024-12-11 13:31:58,335] Trial 4 finished with value: 0.8031039136302294 and parameters: {'n_estimators': 835, 'booster': 'gbtree', 'lambda': 0.6513353311957655, 'alpha': 0.7779659020892746, 'max_depth': 5, 'eta': 0.2503338776540595, 'gamma': 1.0709032267540741, 'min_child_weight': 2, 'subsample': 0.789943629105387, 'colsample_bytree': 0.6493234787411669, 'grow_policy': 'depthwise', 'max_bin': 253}. Best is trial 2 with value: 0.8057354925775979.
# [I 2024-12-11 13:31:58,939] Trial 5 finished with value: 0.7899460188933873 and parameters: {'n_estimators': 1109, 'booster': 'gbtree', 'lambda': 1.6311073954812134, 'alpha': 1.4140078303513866, 'max_depth': 8, 'eta': 0.23366840053892426, 'gamma': 0.223059910550537, 'min_child_weight': 3, 'subsample': 0.6405541708337954, 'colsample_bytree': 0.9020861990564577, 'grow_policy': 'depthwise', 'max_bin': 76}. Best is trial 2 with value: 0.8057354925775979.
# [I 2024-12-11 13:32:00,371] Trial 6 finished with value: 0.7585695006747638 and parameters: {'n_estimators': 924, 'booster': 'dart', 'lambda': 1.275477385239071, 'alpha': 1.7745382724100767, 'max_depth': 6, 'eta': 0.04468233132210749, 'gamma': 2.140021116881762, 'min_child_weight': 6, 'subsample': 0.7964470191493236, 'colsample_bytree': 0.8698385129840963, 'grow_policy': 'lossguide', 'max_bin': 146}. Best is trial 2 with value: 0.8057354925775979.
# [I 2024-12-11 13:32:00,949] Trial 7 finished with value: 0.7954116059379218 and parameters: {'n_estimators': 810, 'booster': 'gbtree', 'lambda': 1.273184412116297, 'alpha': 0.629397606171577, 'max_depth': 7, 'eta': 0.27319427743856695, 'gamma': 0.748627395217476, 'min_child_weight': 3, 'subsample': 0.864442898490067, 'colsample_bytree': 0.6800793579220679, 'grow_policy': 'lossguide', 'max_bin': 94}. Best is trial 2 with value: 0.8057354925775979.
# [I 2024-12-11 13:32:01,475] Trial 8 finished with value: 0.7820512820512822 and parameters: {'n_estimators': 1172, 'booster': 'gbtree', 'lambda': 1.7430497197852477, 'alpha': 1.6075404817213297, 'max_depth': 4, 'eta': 0.26884210956209353, 'gamma': 1.6184873835050364, 'min_child_weight': 6, 'subsample': 0.9136319549732226, 'colsample_bytree': 0.7113012162401523, 'grow_policy': 'lossguide', 'max_bin': 146}. Best is trial 2 with value: 0.8057354925775979.
# [I 2024-12-11 13:32:02,084] Trial 9 finished with value: 0.7638326585695007 and parameters: {'n_estimators': 1128, 'booster': 'gbtree', 'lambda': 1.0219838578525537, 'alpha': 0.8354045952944092, 'max_depth': 4, 'eta': 0.044760956526768016, 'gamma': 1.0135078990394801, 'min_child_weight': 7, 'subsample': 0.7131210262072643, 'colsample_bytree': 0.7815767176101781, 'grow_policy': 'depthwise', 'max_bin': 250}. Best is trial 2 with value: 0.8057354925775979.
# [I 2024-12-11 13:32:03,305] Trial 10 finished with value: 0.7715924426450742 and parameters: {'n_estimators': 1031, 'booster': 'dart', 'lambda': 0.01608709131327013, 'alpha': 0.036905789354024776, 'max_depth': 10, 'eta': 0.1097215877927743, 'gamma': 2.907681818635262, 'min_child_weight': 1, 'subsample': 0.6120962929861637, 'colsample_bytree': 0.8370053559794566, 'grow_policy': 'lossguide', 'max_bin': 197}. Best is trial 2 with value: 0.8057354925775979.
# [I 2024-12-11 13:32:04,844] Trial 11 finished with value: 0.8005398110661268 and parameters: {'n_estimators': 1028, 'booster': 'dart', 'lambda': 0.4138747454946091, 'alpha': 1.2394483523240654, 'max_depth': 10, 'eta': 0.29940812196172323, 'gamma': 1.4813357129151448, 'min_child_weight': 1, 'subsample': 0.6939286756069478, 'colsample_bytree': 0.604629907587962, 'grow_policy': 'depthwise', 'max_bin': 201}. Best is trial 2 with value: 0.8057354925775979.
# [I 2024-12-11 13:32:06,018] Trial 12 finished with value: 0.77165991902834 and parameters: {'n_estimators': 979, 'booster': 'dart', 'lambda': 0.559547485663439, 'alpha': 0.08227355406555037, 'max_depth': 9, 'eta': 0.2210962087050133, 'gamma': 1.9215396924211117, 'min_child_weight': 2, 'subsample': 0.7859887854595823, 'colsample_bytree': 0.8215508389133763, 'grow_policy': 'depthwise', 'max_bin': 187}. Best is trial 2 with value: 0.8057354925775979.
# [I 2024-12-11 13:32:07,356] Trial 13 finished with value: 0.8083670715249662 and parameters: {'n_estimators': 1092, 'booster': 'dart', 'lambda': 0.5445006244427725, 'alpha': 0.42164842684921067, 'max_depth': 3, 'eta': 0.22796789319657884, 'gamma': 1.2143192704588164, 'min_child_weight': 4, 'subsample': 0.7552776672305153, 'colsample_bytree': 0.6540669635907299, 'grow_policy': 'depthwise', 'max_bin': 122}. Best is trial 13 with value: 0.8083670715249662.
# [I 2024-12-11 13:32:08,618] Trial 14 finished with value: 0.7978407557354926 and parameters: {'n_estimators': 1065, 'booster': 'dart', 'lambda': 0.1887156520589479, 'alpha': 0.35152105109460735, 'max_depth': 3, 'eta': 0.20518456111104055, 'gamma': 2.3447334847807757, 'min_child_weight': 4, 'subsample': 0.6424781924237156, 'colsample_bytree': 0.7524140276161262, 'grow_policy': 'depthwise', 'max_bin': 120}. Best is trial 13 with value: 0.8083670715249662.
# [I 2024-12-11 13:32:10,007] Trial 15 finished with value: 0.7901484480431848 and parameters: {'n_estimators': 1195, 'booster': 'dart', 'lambda': 0.7174221792962936, 'alpha': 0.3643398281884435, 'max_depth': 9, 'eta': 0.12995684722584236, 'gamma': 1.5095171223321866, 'min_child_weight': 4, 'subsample': 0.6868936388685195, 'colsample_bytree': 0.8046235783939706, 'grow_policy': 'depthwise', 'max_bin': 125}. Best is trial 13 with value: 0.8083670715249662.
# [I 2024-12-11 13:32:11,244] Trial 16 finished with value: 0.8004048582995951 and parameters: {'n_estimators': 1092, 'booster': 'dart', 'lambda': 0.2913075905677686, 'alpha': 0.1910501495005988, 'max_depth': 3, 'eta': 0.29676074106205547, 'gamma': 2.960710784600434, 'min_child_weight': 5, 'subsample': 0.7399087729223773, 'colsample_bytree': 0.7325344506757501, 'grow_policy': 'depthwise', 'max_bin': 176}. Best is trial 13 with value: 0.8083670715249662.
# [I 2024-12-11 13:32:12,270] Trial 17 finished with value: 0.8004048582995951 and parameters: {'n_estimators': 1144, 'booster': 'dart', 'lambda': 0.751199841968599, 'alpha': 1.13665387281895, 'max_depth': 8, 'eta': 0.24914701669020584, 'gamma': 1.8799259570845717, 'min_child_weight': 2, 'subsample': 0.9486788845418358, 'colsample_bytree': 0.8671601107005014, 'grow_policy': 'depthwise', 'max_bin': 215}. Best is trial 13 with value: 0.8083670715249662.
# [I 2024-12-11 13:32:13,350] Trial 18 finished with value: 0.7822537112010797 and parameters: {'n_estimators': 1069, 'booster': 'dart', 'lambda': 1.9876917273143682, 'alpha': 0.4986406227667024, 'max_depth': 6, 'eta': 0.1463810181926448, 'gamma': 1.1585089549188268, 'min_child_weight': 5, 'subsample': 0.8217609204859784, 'colsample_bytree': 0.6710121003287608, 'grow_policy': 'lossguide', 'max_bin': 68}. Best is trial 13 with value: 0.8083670715249662.
# [I 2024-12-11 13:32:14,424] Trial 19 finished with value: 0.7717273954116058 and parameters: {'n_estimators': 1006, 'booster': 'dart', 'lambda': 0.4531444412544287, 'alpha': 1.978933049808698, 'max_depth': 8, 'eta': 0.09606624737204414, 'gamma': 2.5735317074671, 'min_child_weight': 4, 'subsample': 0.749159546947392, 'colsample_bytree': 0.6985436071351779, 'grow_policy': 'depthwise', 'max_bin': 128}. Best is trial 13 with value: 0.8083670715249662.
# Best trial: {'n_estimators': 1092, 'booster': 'dart', 'lambda': 0.5445006244427725, 'alpha': 0.42164842684921067, 'max_depth': 3, 'eta': 0.22796789319657884, 'gamma': 1.2143192704588164, 'min_child_weight': 4, 'subsample': 0.7552776672305153, 'colsample_bytree': 0.6540669635907299, 'grow_policy': 'depthwise', 'max_bin': 122}

# %% [markdown]
# #### Testing

# %%
best_params = {'n_estimators': 990, 'booster': 'gbtree', 'lambda': 0.6465611069976087, 'alpha': 1.1963315346529115, 'max_depth': 3, 'eta': 0.11623676467831479, 'gamma': 1.6510175761428012, 'min_child_weight': 1, 'subsample': 0.6628472786517728, 'colsample_bytree': 0.874236658152416, 'grow_policy': 'depthwise', 'max_bin': 109}
model = xgb.XGBClassifier(**best_params)
model.fit(X, y)
# Out:
# XGBClassifier(alpha=1.1963315346529115, base_score=None, booster='gbtree',
#               callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.874236658152416, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eta=0.11623676467831479, eval_metric=None, feature_types=None,
#               gamma=1.6510175761428012, grow_policy='depthwise',
#               importance_type=None, interaction_constraints=None,
#               lambda=0.6465611069976087, learning_rate=None, max_bin=109,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=990, ...)

# %%
print('XGBoost scores')
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"RocAuc: {roc_auc_score(y_test, y_pred)}")
print(f"F1 : {f1_score(y_test, y_pred)}")
# Out:
# XGBoost scores
# Accuracy: 0.7682926829268293
# RocAuc: 0.7154471544715448
# F1 : 0.5681818181818182

# %% [markdown]
# ## LGBM

# %% [markdown]
# #### Parameters research

# %%
def objective(trial):
    param = {
        'num_leaves': trial.suggest_int('num_leaves', 40, 70),
        'max_depth': trial.suggest_int('max_depth', 6, 14),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 40, 70),
        'lambda_l1': trial.suggest_float('lambda_l1', 0.1, 2),
        'lambda_l2': trial.suggest_float('lambda_l2', 0.1, 2),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 0.95),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 0.95),
        'bagging_freq': trial.suggest_int('bagging_freq', 5, 15),
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'metric': 'binary_error',
        'n_estimators': trial.suggest_int('n_estimators', 100, 500)        
    }
    
    kf = StratifiedKFold(n_splits=20, shuffle=True, random_state=42)
    accuracies = []
    
    for train_index, valid_index in kf.split(X, y):
        X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
        y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]

        scaler = MinMaxScaler()
        X_train.loc[:, num_col] = scaler.fit_transform(X_train[num_col])
        X_valid.loc[:, num_col] = scaler.transform(X_valid[num_col])
        
        model = lgb.LGBMClassifier(**param, early_stopping_rounds=25, verbose=-1)
        model.fit(X_train, y_train, 
                  eval_set=[(X_valid, y_valid)], 
                  eval_metric='binary_error')
        
        preds = model.predict(X_valid)
        accuracies.append(accuracy_score(y_valid, preds))
    
    mean_accuracy = np.mean(accuracies)
    return mean_accuracy

# Create Optuna study
study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=42), pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=3))

# Optimize
study.optimize(objective, n_trials=20)

# Print best parameters
print("Best trial:", study.best_trial.params)
# Out:
# [I 2024-12-11 13:32:14,831] A new study created in memory with name: no-name-72610895-df3c-46ce-8d84-9a44c574e00c
# [I 2024-12-11 13:32:15,250] Trial 0 finished with value: 0.8136842105263156 and parameters: {'num_leaves': 51, 'max_depth': 14, 'learning_rate': 0.07587945476302646, 'min_data_in_leaf': 58, 'lambda_l1': 0.39643541684062933, 'lambda_l2': 0.39638958863878504, 'feature_fraction': 0.6203292642588698, 'bagging_fraction': 0.9031616510212273, 'bagging_freq': 11, 'n_estimators': 383}. Best is trial 0 with value: 0.8136842105263156.
# [I 2024-12-11 13:32:15,650] Trial 1 finished with value: 0.821578947368421 and parameters: {'num_leaves': 40, 'max_depth': 14, 'learning_rate': 0.08491983767203796, 'min_data_in_leaf': 46, 'lambda_l1': 0.4454674376934912, 'lambda_l2': 0.4484685687215243, 'feature_fraction': 0.7064847850358382, 'bagging_fraction': 0.7836647510712832, 'bagging_freq': 9, 'n_estimators': 216}. Best is trial 1 with value: 0.821578947368421.
# [I 2024-12-11 13:32:16,012] Trial 2 finished with value: 0.7506578947368421 and parameters: {'num_leaves': 58, 'max_depth': 7, 'learning_rate': 0.03629301836816964, 'min_data_in_leaf': 51, 'lambda_l1': 0.9665329700123682, 'lambda_l2': 1.5918343266467259, 'feature_fraction': 0.6698858237554259, 'bagging_fraction': 0.779982053444764, 'bagging_freq': 11, 'n_estimators': 118}. Best is trial 1 with value: 0.821578947368421.
# [I 2024-12-11 13:32:16,324] Trial 3 finished with value: 0.7506578947368421 and parameters: {'num_leaves': 58, 'max_depth': 7, 'learning_rate': 0.015854643368675158, 'min_data_in_leaf': 69, 'lambda_l1': 1.9347008628416629, 'lambda_l2': 1.6359549614212763, 'feature_fraction': 0.7066148192106797, 'bagging_fraction': 0.6341852399022343, 'bagging_freq': 12, 'n_estimators': 276}. Best is trial 1 with value: 0.821578947368421.
# [I 2024-12-11 13:32:16,610] Trial 4 finished with value: 0.7506578947368421 and parameters: {'num_leaves': 43, 'max_depth': 10, 'learning_rate': 0.013094966900369657, 'min_data_in_leaf': 68, 'lambda_l1': 0.5916819650400321, 'lambda_l2': 1.3587923402725657, 'feature_fraction': 0.7090988766312938, 'bagging_fraction': 0.7820238074122338, 'bagging_freq': 11, 'n_estimators': 174}. Best is trial 1 with value: 0.821578947368421.
# [I 2024-12-11 13:32:16,962] Trial 5 finished with value: 0.8057894736842103 and parameters: {'num_leaves': 70, 'max_depth': 12, 'learning_rate': 0.09455490474077703, 'min_data_in_leaf': 67, 'lambda_l1': 1.2360099597410619, 'lambda_l2': 1.851561046543922, 'feature_fraction': 0.6309723757181718, 'bagging_fraction': 0.6685940018467008, 'bagging_freq': 5, 'n_estimators': 230}. Best is trial 1 with value: 0.821578947368421.
# [I 2024-12-11 13:32:17,376] Trial 6 finished with value: 0.8240789473684208 and parameters: {'num_leaves': 52, 'max_depth': 8, 'learning_rate': 0.08458637582367365, 'min_data_in_leaf': 51, 'lambda_l1': 0.6337755684060234, 'lambda_l2': 1.131122558000672, 'feature_fraction': 0.6493234787411669, 'bagging_fraction': 0.8807689432639139, 'bagging_freq': 5, 'n_estimators': 495}. Best is trial 6 with value: 0.8240789473684208.
# [I 2024-12-11 13:32:17,679] Trial 7 finished with value: 0.7506578947368421 and parameters: {'num_leaves': 63, 'max_depth': 7, 'learning_rate': 0.010496990541124216, 'min_data_in_leaf': 65, 'lambda_l1': 1.4430289533104725, 'lambda_l2': 1.485113619277876, 'feature_fraction': 0.869944621340081, 'bagging_fraction': 0.6259156281069316, 'bagging_freq': 8, 'n_estimators': 146}. Best is trial 6 with value: 0.8240789473684208.
# [I 2024-12-11 13:32:18,057] Trial 8 finished with value: 0.7872368421052631 and parameters: {'num_leaves': 66, 'max_depth': 11, 'learning_rate': 0.03978082223673843, 'min_data_in_leaf': 41, 'lambda_l1': 0.6908664112597581, 'lambda_l2': 0.7178483118508193, 'feature_fraction': 0.8553621624183224, 'bagging_fraction': 0.8231451149743245, 'bagging_freq': 14, 'n_estimators': 289}. Best is trial 6 with value: 0.8240789473684208.
# [I 2024-12-11 13:32:18,419] Trial 9 finished with value: 0.821578947368421 and parameters: {'num_leaves': 43, 'max_depth': 12, 'learning_rate': 0.07847065437552077, 'min_data_in_leaf': 57, 'lambda_l1': 1.5648376419136658, 'lambda_l2': 1.0382116330923423, 'feature_fraction': 0.7829564902836978, 'bagging_fraction': 0.7496393564254924, 'bagging_freq': 5, 'n_estimators': 143}. Best is trial 6 with value: 0.8240789473684208.
# [I 2024-12-11 13:32:18,836] Trial 10 finished with value: 0.8267105263157895 and parameters: {'num_leaves': 49, 'max_depth': 9, 'learning_rate': 0.06200670130016324, 'min_data_in_leaf': 50, 'lambda_l1': 0.14204866286063667, 'lambda_l2': 1.057386905837475, 'feature_fraction': 0.9359197610808969, 'bagging_fraction': 0.9405368942967434, 'bagging_freq': 7, 'n_estimators': 497}. Best is trial 10 with value: 0.8267105263157895.
# [I 2024-12-11 13:32:19,293] Trial 11 finished with value: 0.8240789473684209 and parameters: {'num_leaves': 50, 'max_depth': 9, 'learning_rate': 0.06118173559795435, 'min_data_in_leaf': 51, 'lambda_l1': 0.13416050665104917, 'lambda_l2': 0.9862509741592519, 'feature_fraction': 0.946832612318891, 'bagging_fraction': 0.9496256292320587, 'bagging_freq': 7, 'n_estimators': 489}. Best is trial 10 with value: 0.8267105263157895.
# [I 2024-12-11 13:32:19,709] Trial 12 finished with value: 0.8214473684210525 and parameters: {'num_leaves': 48, 'max_depth': 9, 'learning_rate': 0.06168833905761387, 'min_data_in_leaf': 50, 'lambda_l1': 0.12881954501097279, 'lambda_l2': 0.8437349697036634, 'feature_fraction': 0.9472129397950677, 'bagging_fraction': 0.9486057861116024, 'bagging_freq': 7, 'n_estimators': 499}. Best is trial 10 with value: 0.8267105263157895.
# [I 2024-12-11 13:32:20,123] Trial 13 finished with value: 0.805657894736842 and parameters: {'num_leaves': 48, 'max_depth': 9, 'learning_rate': 0.05772603501663638, 'min_data_in_leaf': 45, 'lambda_l1': 0.1917730543960247, 'lambda_l2': 1.1583682713686116, 'feature_fraction': 0.9454385411782564, 'bagging_fraction': 0.9378682811229091, 'bagging_freq': 7, 'n_estimators': 406}. Best is trial 10 with value: 0.8267105263157895.
# [I 2024-12-11 13:32:20,505] Trial 14 finished with value: 0.8110526315789472 and parameters: {'num_leaves': 55, 'max_depth': 9, 'learning_rate': 0.04736859547269702, 'min_data_in_leaf': 61, 'lambda_l1': 0.9594199944674557, 'lambda_l2': 0.7079493842672582, 'feature_fraction': 0.8799641591596776, 'bagging_fraction': 0.8648339346839145, 'bagging_freq': 7, 'n_estimators': 420}. Best is trial 10 with value: 0.8267105263157895.
# [I 2024-12-11 13:32:20,944] Trial 15 finished with value: 0.821578947368421 and parameters: {'num_leaves': 47, 'max_depth': 10, 'learning_rate': 0.06483339605894614, 'min_data_in_leaf': 54, 'lambda_l1': 0.10900622734086929, 'lambda_l2': 0.13973577631846734, 'feature_fraction': 0.9046229137945205, 'bagging_fraction': 0.8471034865825814, 'bagging_freq': 9, 'n_estimators': 355}. Best is trial 10 with value: 0.8267105263157895.
# [I 2024-12-11 13:32:21,374] Trial 16 finished with value: 0.8109210526315789 and parameters: {'num_leaves': 54, 'max_depth': 6, 'learning_rate': 0.06980801836202169, 'min_data_in_leaf': 46, 'lambda_l1': 0.37697570060276, 'lambda_l2': 0.9431175035823829, 'feature_fraction': 0.8123334609943698, 'bagging_fraction': 0.9164483291226845, 'bagging_freq': 15, 'n_estimators': 446}. Best is trial 10 with value: 0.8267105263157895.
# [I 2024-12-11 13:32:21,775] Trial 17 finished with value: 0.7977631578947367 and parameters: {'num_leaves': 59, 'max_depth': 11, 'learning_rate': 0.04837119994846849, 'min_data_in_leaf': 42, 'lambda_l1': 0.8162923444561185, 'lambda_l2': 1.2033542709409994, 'feature_fraction': 0.9127597716627306, 'bagging_fraction': 0.722186388565255, 'bagging_freq': 6, 'n_estimators': 338}. Best is trial 10 with value: 0.8267105263157895.
# [I 2024-12-11 13:32:22,139] Trial 18 finished with value: 0.7506578947368421 and parameters: {'num_leaves': 45, 'max_depth': 8, 'learning_rate': 0.026669289362145812, 'min_data_in_leaf': 53, 'lambda_l1': 0.35856065538821646, 'lambda_l2': 0.5824390666459933, 'feature_fraction': 0.8112101436309626, 'bagging_fraction': 0.8214206374668114, 'bagging_freq': 9, 'n_estimators': 459}. Best is trial 10 with value: 0.8267105263157895.
# [I 2024-12-11 13:32:22,564] Trial 19 finished with value: 0.8135526315789473 and parameters: {'num_leaves': 51, 'max_depth': 8, 'learning_rate': 0.09966028459647208, 'min_data_in_leaf': 48, 'lambda_l1': 1.863395449642458, 'lambda_l2': 1.3157008867639584, 'feature_fraction': 0.8443338240018903, 'bagging_fraction': 0.9034162454967858, 'bagging_freq': 8, 'n_estimators': 448}. Best is trial 10 with value: 0.8267105263157895.
# Best trial: {'num_leaves': 49, 'max_depth': 9, 'learning_rate': 0.06200670130016324, 'min_data_in_leaf': 50, 'lambda_l1': 0.14204866286063667, 'lambda_l2': 1.057386905837475, 'feature_fraction': 0.9359197610808969, 'bagging_fraction': 0.9405368942967434, 'bagging_freq': 7, 'n_estimators': 497}

# %% [markdown]
# #### Testing

# %%
best_params = {'num_leaves': 59, 'max_depth': 8, 'learning_rate': 0.09284017157461277, 'min_data_in_leaf': 66, 'lambda_l1': 0.28003957357849574, 'lambda_l2': 0.1829917366656828, 'feature_fraction': 0.7752015772882725, 'bagging_fraction': 0.6682843033321142, 'bagging_freq': 6, 'n_estimators': 186}
model = lgb.LGBMClassifier(**best_params, verbose = -1)
model.fit(X, y)
# Out:
# LGBMClassifier(bagging_fraction=0.6682843033321142, bagging_freq=6,
#                feature_fraction=0.7752015772882725,
#                lambda_l1=0.28003957357849574, lambda_l2=0.1829917366656828,
#                learning_rate=0.09284017157461277, max_depth=8,
#                min_data_in_leaf=66, n_estimators=186, num_leaves=59,
#                verbose=-1)

# %%
print('LGBM scores')
y_pred = model.predict(X_test)
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"RocAuc: {roc_auc_score(y_test, y_pred)}")
print(f"F1 : {f1_score(y_test, y_pred)}")
# Out:
# LGBM scores
# Accuracy: 0.7621951219512195
# RocAuc: 0.7032520325203253
# F1 : 0.5517241379310345

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 9
#       6 # Iterate through models
#       7 for model_name, model in models.items():
#       8     # Train the model
# ----> 9     model.fit(X_train, y_train)
#      11     # Predict on test data
#      12     y_pred = model.predict(X_test)
#
# NameError: name 'X_train' is not defined
